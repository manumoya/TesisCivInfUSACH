# %%
# Imports necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('ggplot')
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
#cargamos los datos de entrada
df = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/wf1_train_fin.csv", index_col=0)

# Ver los 1ros registros
#data.head()

# %% [markdown]
# ## Descripción básica del dataset

# %%
df.head()
# Out:
#    hors    ws      wd  anno  mes    wp1
# 0     1  2.47  108.68  2009    7  0.085
# 1     2  2.40  114.31  2009    7  0.020
# 2     3  2.51  118.71  2009    7  0.060
# 3     4  2.73  120.86  2009    7  0.045
# 4     5  2.93  120.13  2009    7  0.035

# %% [markdown]
# ## Preparación de Datos

# %%
data_train, data_test = train_test_split(data, random_state=200)

dataset_train = data_train.values
x_train = dataset_train[:,1:3]
y_train = dataset_train[:,5]

dataset_test = data_test.values
x_test = dataset_test[:,1:3]
y_test = dataset_test[:,5]

# %% [markdown]
# ## Leer datos de predicción Regresión Lineal

# %%
## lee prediccion regresion lineal
pred_reg_lin = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/pred_iter1_reglin.csv", index_col=0)

## Mostrar detalles de archivo
pred_reg_lin.head()
# Out:
#        pred
# 0  0.305028
# 1  0.279934
# 2  0.230071
# 3  0.218112
# 4  0.266478

# %%
## lee prediccion regresion lineal
pred_reg_redNN = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/pred_iter1_redNN.csv", index_col=0)

## Mostrar detalles de archivo
pred_reg_redNN.head()
# Out:
#        pred
# 0  0.329028
# 1  0.276674
# 2  0.272816
# 3  0.205926
# 4  0.248517

# %%
## lee prediccion regresion lineal
pred_reg_deepNN = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/pred_iter1_deepNN.csv", index_col=0)

## Mostrar detalles de archivo
pred_reg_deepNN.head()
# Out:
#        pred
# 0  0.315117
# 1  0.285313
# 2  0.264521
# 3  0.180098
# 4  0.238049

# %%
## lee prediccion regresion lineal
pred_reg_LSTM = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/pred_iter1_LSTM.csv", index_col=0)

## Mostrar detalles de archivo
pred_reg_LSTM.head()
# Out:
#        pred
# 0  0.363280
# 1  0.274820
# 2  0.297329
# 3  0.178537
# 4  0.252457

# %% [markdown]
# ## Graficar

# %%
pred_reg_LSTM_plot = pred_reg_LSTM.values
pred_reg_deepNN_plot= pred_reg_deepNN.values
pred_reg_lin_plot = pred_reg_lin.values
pred_reg_redNN_plot = pred_reg_redNN.values
y_test_plot = y_test[2000:2100]

# %%
plt.plot(pred_reg_lin_plot, label ="y pred reg lin")
plt.plot(pred_reg_redNN_plot, label ="y pred red NN")
plt.plot(pred_reg_deepNN_plot, label ="y pred red Prof")
plt.plot(pred_reg_deepNN_plot, label ="y pred red LSTM")
plt.plot(y_test_plot, label ="y  test")
#plt.plot(trainPredictPlot, label ="train pred" )
#plt.title("NN con %i neuronas, correlacion: %.2f" % (neuronas, corr[1][0] * 100))
plt.ylabel("Energía Generada")
plt.xlabel("Muestras")
plt.legend()
plt.show()


#plt.plot(df.real, df.reglin, "ro")
#plt.xlabel("real")
#plt.ylabel("reg lin")


#plot = df[['real', 'reglin', 'redneu', 'deep']].plot(figsize=(10, 8))
