# %%
# Imports necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

#cargamos los datos de entrada
df = pd.read_csv("/Users/manuelmoya/Documents/USACH/2019-1er/Tesis/1.Desarrollo/05.AnalisisDatos/Datos/compara_resultado.csv",sep=",")
#veamos cuantas dimensiones y registros contiene

# %% [markdown]
# ## Descripción básica del dataset

# %%
df.head(5)
# Out:
#    hors   real    reglin  redneu  deep
# 0     1  0.521  0.337755     NaN   NaN
# 1     2  0.351  0.335654     NaN   NaN
# 2     3  0.536  0.319818     NaN   NaN
# 3     4  0.617  0.295867     NaN   NaN
# 4     5  0.566  0.267678     NaN   NaN

# %%
#plt.plot(df.real, df.reglin, "ro")
#plt.xlabel("real")
#plt.ylabel("reg lin")


plot = df[['real', 'reglin', 'redneu', 'deep']].plot(figsize=(10, 8))
